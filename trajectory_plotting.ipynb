# %%
# Import packages
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import rmgpy.constants as constants

# %%
# Set filename
filename = "trajectories_14.txt"
filename = "/Users/lancebettinson/scratch/nuts_out/trajectories_48.txt"
# Open file and populate data structure
phi = []
E = []
grad = []
with open(filename,'r') as f:
    line = f.readline()
    line = f.readline()
    while line:
        split = line.split('\t')
        phi_ = split[0].strip('\\[').strip('\\]').split(' ')
        while '' in phi_:
            phi_.remove('')
        phi.append([float(p) for p in phi_])
        #phi.append(np.array(split[0]))
        E.append(float(split[1]))
        line = f.readline()
    f.close()

# %%
# Convert to degrees
phi = np.array(phi)
phi = phi*180/np.pi

# %%
# Change matplotlib backend
# %matplotlib notebook
# Create figure and add axes
fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot(111)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
show_last = len(phi)
show_first = len(phi)
# Plot all position vals
# Get colors from coolwarm colormap
colors = plt.get_cmap('cividis', show_last)
beta = 1/(constants.kB*300)*constants.E_h
scats = []
#area = [(100*E[i])**3 for i in range(len(phi))]
area = [1E3*np.exp(-beta*E[i]) for i in range(len(phi))]
color = [1E3*np.exp(-beta*E[i]) for i in range(len(phi))]
ax.scatter(phi[-show_last:show_first,1],
           phi[-show_last:show_first,0],
           s=area[-show_last:show_first],
           c=color[-show_last:show_first],
           alpha=0.7)
#for i,p in enumerate(phi):
#    ax.scatter(p[1],p[2],color=colors(i))
    #scats.append(ax.scatter(x=p[0],y=p[1],color=colors(i)))
#ax.plot(phi[:,0],phi[:,1],color='gray')
plt.show()
plt.tight_layout()

# %%
# Import animation package
from matplotlib.animation import FuncAnimation

# %%
# Create variable reference to plot
#scat = ax.scatter([], [])# Add text annotation and create variable reference

# %%
# Animation function
def animate(i, scats):
    #scat.set_array(phi[i][:])
    return scats[i]

# %%
# Create animation
#ani = FuncAnimation(fig=fig, func=animate, frames=range(len(phi)), interval=100, repeat=True,
                   blit=False, fargs=(colors, scats))
# Out:
#   File "<ipython-input-23-39cf6c907b1f>", line 3
#     blit=False, fargs=(colors, scats))
#     ^
# IndentationError: unexpected indent

# %%
# Make entire plot visible
fig.tight_layout()

# %%
# Save and show animation
#ani.save('TrajectoryPlot.gif', writer='imagemagick', fps=2)
# Out:
# MovieWriter stderr:
# convert: unexpected end-of-file '-': No such file or directory @ error/rgb.c/ReadRGBImage/247.
# convert: no images defined `TrajectoryPlot.gif' @ error/convert.c/ConvertImageCommand/3285.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda2/envs/rmg_env/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     229         try:
# --> 230             yield self
#     231         finally:
#
# ~/miniconda2/envs/rmg_env/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1138                     # Clear the initial frame
# -> 1139                     anim._init_draw()
#    1140                 frame_number = 0
#
# ...

# %%
print(phi[:][0],phi[:][1])
# Out:
# [0. 0.] [118.49223049 147.86488951]

# %%
plt.show()
